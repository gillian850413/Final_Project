# %% [markdown]
# # Youtube Video & Channel Data Analysis
# By Pin-Huey Chiang, Hung-Yi Lin
#
# **This data analysis provided information for people who wants to become Youtuber of how to earn money and become a successful Youtuber.**
#
# **Possible factors to become a successful Youtuber:**
# 1. Youtube channel types (types that most people like to watch)
# 2. Have many subscribers and video views
# 3. Youtube channels that have more trending videos
#
# **Measurements of whether a Youtube channel is successful:**
# 1. Amount of money they earned
# 2. Number of subscribers
# 3. Number of video views
# 4. Number of trending videos
# 5. Film the right category
#
# **Limitations:**
# 1. The data only includes the Top Youtube data, it might not be good for generalization.
# 2. The trending video data only collect 8 month data

# %% [markdown]
# ## Hypothesis
# 1. Top 250 ranking Youtubers (by grade, subs, views) in the U.S. will have more chances to earn more money than office workers
# 2. As a full-time Youtuber, it will be more profitable to film entertainment videos than other types of videos such as comedy, music, fashion, knowledge, and etc
# 3. Entertainment videos will likely to trend more than other types of videos such as comedy, music, fashion, knowledge, and etc
# 4. Top 250 Youtubers may have more trending videos than other Youtube channels.

# %% [markdown]
# **Part 2: What video types people like the most? / Is there a relationship between trending videos and Top 250 Youtubers?**

# %% [markdown]
# ## Hypothesis 3
# **Youtube Trending: Know what viewers want to see the most**
#
# YouTube Trendings aims to let the users know what’s happening on YouTube and in the world. Thus, YouTube trending videos shows that they are appealing to a wide range of viewers, capture the breadth of what’s happening on YouTube and in the world, or surprising or novel in the specific moment. Trending Youtube videos are determined by several signals such as
# - view count
# - the rate of growth in views, where views are coming from (including outside of YouTube)
# - the age of the video.
#
# This means that the highest view count on a given day may not be #1 on Trending. In addition, even if one video meets all the criteria, it does not mean it will definitly enter Trending. The Trending system tries to choose videos that will be most relevant to their viewers and most reflective of the broad content on the platform. Therefore, by analyzing the Youtube trending videos, we can get an insight of what types of videos Youtube thinks viewers would want to see the most, and reflects to the events that happened in the given time.
#
# Source: https://support.google.com/youtube/answer/7239739?hl=en

# %% [markdown]
# ### Entertainment videos will likely to trend more than other types of videos such as comedy, music, fashion, knowledge.

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
trending_df = pd.read_csv('data/USvideos.csv')
category_id = pd.read_json('data/US_category_id.json')

# %%
len(trending_df)
# Out:
# 40949

# %% [markdown]
# ### Data Preprocessing of Trending Video Dataset
# 1. change category id to category name based on the US_category_id.json file
# 2. change the trending date and publish time to pandas timestamp
# 3. calculate the days one video spent to trend

# %%
# import category_id json file and dataframe 
def catId_to_name(catid, videodf):
    """ This function replaces category id to category name based on the json file.

    :param catid: category id which is resorded in the US_category_id.json file
    :param videodf: youtube video dataframe
    :return: category dictionary. key = id, value = category name
    """
    cat_dict = {}
    for i in range(len(catid)):
        id = int(category_id['items'][i]['id'])
        name = catid['items'][i]['snippet']['title']
        cat_dict[id] = name
    return cat_dict

# %%
# add category name to the dataframe
category_dict = catId_to_name(category_id, trending_df)
trending_df['category_name'] = trending_df['category_id'].replace(category_dict)

# %%
# change publish time type to datetime
trending_df['publish_time'] = trending_df.publish_time.str[:10]
trending_df['publish_time'] = pd.to_datetime(trending_df['publish_time'])

# %%
# change trending date format to datetime format
trending_df['trending_date'] = trending_df['trending_date'].apply(lambda date: re.sub(r'(\d+).(\d+).(\d+)', r'20\1-\3-\2', date))
trending_df['trending_date'] = pd.to_datetime(trending_df['trending_date'])

# %%
# show the earliest and latest video publish date
min(trending_df['publish_time']), max(trending_df['publish_time'])
# Out:
# (Timestamp('2006-07-23 00:00:00'), Timestamp('2018-06-14 00:00:00'))

# %%
# show the earliest and latest video trending date, which also represents the data capture time period
min(trending_df['trending_date']), max(trending_df['trending_date'])
# Out:
# (Timestamp('2017-11-14 00:00:00'), Timestamp('2018-06-14 00:00:00'))

# %%
# calculate the days one video spent to become a trending video 
trending_df['days_spent_to_trend'] = trending_df['trending_date'] - trending_df['publish_time']
days = trending_df['days_spent_to_trend'].astype(str).str.split(" ", n = 1, expand = True)
trending_df['days_spent_to_trend'] = days[0].astype(int)

# %%
trending_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id publish_time  \
# 0           22   2017-11-13
# 1           24   2017-11-13
# 2           23   2017-11-12
# 3           24   2017-11-13
# 4           24   2017-11-12
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description   category_name  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  People & Blogs
# 1  One year after the presidential election, John...   Entertainment
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...          Comedy
# 3  Today we find out if Link is a Nickelback amat...   Entertainment
# 4  I know it's been a while since we did this sho...   Entertainment
#
#    days_spent_to_trend
# 0                    1
# 1                    1
# 2                    2
# 3                    1
# 4                    2

# %% [markdown]
# ### Trending Video Analysis

# %% [markdown]
# Show the earliest and latest video publish date, earliest and latest video trending data

# %%
trending_df['Month'] = trending_df['trending_date'].dt.month.astype(str) # .apply(lambda x: look_up[x])
trending_df['Year'] = trending_df['trending_date'].dt.year.astype(str)
trending_df['trend_MY'] = trending_df['Year']+'-'+trending_df['Month']
trending_df['trend_MY'] = pd.to_datetime(trending_df['trend_MY'])

# create a pivot table to see the number of trendings in each category in each month
trend_monpi = pd.pivot_table(trending_df, values=['category_id'], index=['trend_MY'], columns=['category_name'], aggfunc='count').fillna(0)

trend_monpi.index = ['Nov 2017', 'Dec 2017', 'Jan 2018', 'Feb 2018', 'Mar 2018', 'Apr 2018', 'May 2018', 'Jun 2018']
trend_monpi.columns = trend_monpi.columns.droplevel()

# %%
trend_monpi
# Out:
# category_name  Autos & Vehicles  Comedy  Education  Entertainment  \
# Nov 2017                   47.0   315.0      138.0          790.0
# Dec 2017                   58.0   579.0      224.0         1549.0
# Jan 2018                   91.0   465.0      254.0         1288.0
# Feb 2018                  129.0   423.0      235.0         1243.0
# Mar 2018                   16.0   524.0      328.0         1537.0
# Apr 2018                   34.0   407.0      204.0         1160.0
# May 2018                    9.0   510.0      207.0         1701.0
# Jun 2018                    0.0   234.0       66.0          696.0
#
# category_name  Film & Animation  Gaming  Howto & Style   Music  \
# Nov 2017                  174.0    22.0          319.0   613.0
# Dec 2017                  360.0    63.0          560.0   950.0
# Jan 2018                  354.0   112.0          551.0   758.0
# Feb 2018                  295.0    75.0          479.0   777.0
# Mar 2018                  337.0   122.0          810.0   810.0
# Apr 2018                  264.0    92.0          557.0   747.0
# May 2018                  355.0   180.0          617.0  1121.0
# Jun 2018                  206.0   151.0          253.0   696.0
#
# category_name  News & Politics  Nonprofits & Activism  People & Blogs  \
# Nov 2017                 221.0                    1.0           247.0
# Dec 2017                 547.0                   13.0           518.0
# Jan 2018                 500.0                   16.0           467.0
# Feb 2018                 521.0                   18.0           442.0
# Mar 2018                 195.0                    0.0           508.0
# Apr 2018                 164.0                    0.0           471.0
# May 2018                 276.0                    5.0           401.0
# Jun 2018                  63.0                    4.0           156.0
#
# category_name  Pets & Animals  Science & Technology  Shows  Sports  \
# Nov 2017                 56.0                 237.0    0.0   195.0
# Dec 2017                127.0                 289.0    9.0   278.0
# Jan 2018                200.0                 347.0    7.0   330.0
# Feb 2018                156.0                 385.0    0.0   321.0
# Mar 2018                136.0                 446.0    0.0   334.0
# Apr 2018                 88.0                 251.0   16.0   297.0
# May 2018                101.0                 336.0   19.0   332.0
# Jun 2018                 56.0                 110.0    6.0    87.0
#
# category_name  Travel & Events
# Nov 2017                  25.0
# Dec 2017                  76.0
# Jan 2018                  56.0
# Feb 2018                  72.0
# Mar 2018                  80.0
# Apr 2018                  48.0
# May 2018                  29.0
# Jun 2018                  16.0

# %%
#calculate the percentage of number of trending videos per month in each category
trend_monpi_percent = (trend_monpi / trend_monpi.sum(axis = 0, skipna = True)).round(2)

# %%
# plt.subplots(figsize=(12,5))
# sns.heatmap(trend_monpi_percent, annot=True, cmap="YlGnBu")

cm = sns.light_palette(sns.color_palette()[6], as_cmap=True)
s = trend_monpi_percent.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_978d324e_6659_11e9_97b1_acde48001122row0_col0 {
#             background-color:  #f2c1e3;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col1 {
#             background-color:  #f6d3eb;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col2 {
#             background-color:  #f5cde9;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col3 {
#             background-color:  #f8dff0;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col4 {
#             background-color:  #fbeaf6;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col5 {
#             background-color:  #fbeaf6;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col6 {
#             background-color:  #f7daee;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col7 {
#             background-color:  #fbeaf6;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col8 {
#             background-color:  #f3c6e5;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col9 {
#             background-color:  #f9e3f2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col10 {
#             background-color:  #f4cbe8;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col11 {
#             background-color:  #fbeaf6;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col12 {
#             background-color:  #f2c1e3;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col13 {
#             background-color:  #fbeaf6;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col14 {
#             background-color:  #f0b6de;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row0_col15 {
#             background-color:  #f8dcef;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col0 {
#             background-color:  #f0b7df;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col1 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col2 {
#             background-color:  #eca2d5;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col3 {
#             background-color:  #e582c7;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col4 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col5 {
#             background-color:  #f4cce8;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col6 {
#             background-color:  #eda8d8;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col7 {
#             background-color:  #e994cf;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col8 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col9 {
#             background-color:  #ea97d0;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col10 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col11 {
#             background-color:  #efb0dc;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col12 {
#             background-color:  #efb1dc;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col13 {
#             background-color:  #efb2dc;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col14 {
#             background-color:  #e78ccb;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row1_col15 {
#             background-color:  #e47ec5;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col0 {
#             background-color:  #ea99d1;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col1 {
#             background-color:  #eca5d7;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col2 {
#             background-color:  #ea9bd2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col3 {
#             background-color:  #eca5d7;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col4 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col5 {
#             background-color:  #eda7d8;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col6 {
#             background-color:  #efb0dc;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col7 {
#             background-color:  #f2bfe2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col8 {
#             background-color:  #e583c7;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col9 {
#             background-color:  #e685c8;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col10 {
#             background-color:  #e581c7;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col11 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col12 {
#             background-color:  #eba0d4;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col13 {
#             background-color:  #f2c0e3;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col14 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row2_col15 {
#             background-color:  #eca2d5;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col0 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col1 {
#             background-color:  #efb1dc;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col2 {
#             background-color:  #eca2d5;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col3 {
#             background-color:  #efb1dc;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col4 {
#             background-color:  #e993cf;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col5 {
#             background-color:  #f3c6e5;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col6 {
#             background-color:  #f1b9df;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col7 {
#             background-color:  #f2bfe2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col8 {
#             background-color:  #e47dc5;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col9 {
#             background-color:  #e377c2;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col10 {
#             background-color:  #e78ccb;
#             color:  #000000;
#         }    #T_978d324e_6659_11e9_97b1_acde48001122row3_col11 {
#             background-color:  #ea9bd2;

# %% [markdown]
# The type of videos audience likes to see the most may reflect the current events happened in US in a specific month.

# %%
#check the statistic summary of views in each category
view_describe = trending_df[['category_name', 'views']].groupby('category_name').describe()
view_describe
# Out:
#                         views                                                  \
#                         count          mean           std      min        25%
# category_name
# Autos & Vehicles        384.0  1.355965e+06  3.373464e+06   2860.0  104652.75
# Comedy                 3457.0  1.480308e+06  2.009899e+06   1807.0  351261.00
# Education              1656.0  7.129408e+05  8.792676e+05    773.0  249115.25
# Entertainment          9964.0  2.067883e+06  5.815996e+06    798.0  273394.75
# Film & Animation       2345.0  3.106250e+06  5.576255e+06    943.0  302850.00
# Gaming                  817.0  2.620831e+06  3.165318e+06   1237.0  530676.00
# Howto & Style          4146.0  9.837301e+05  1.928995e+06   1107.0  215422.25
# Music                  6472.0  6.201003e+06  1.545988e+07   1591.0  382714.75
# News & Politics        2487.0  5.925877e+05  1.118918e+06    549.0   50855.00
# Nonprofits & Activism    57.0  2.963884e+06  7.131112e+06   1456.0   11453.00
# People & Blogs         3210.0  1.531835e+06  3.459637e+06    884.0  202658.50
# Pets & Animals          920.0  8.311435e+05  1.102091e+06   3393.0  185072.25
# Science & Technology   2401.0  1.452627e+06  3.445705e+06    983.0  239189.00
# Shows                    57.0  9.035273e+05  5.108668e+05  36609.0  178191.00
# Sports                 2174.0  2.025969e+06  4.017255e+06    658.0  194181.50
# Travel & Events         402.0  8.546196e+05  1.918995e+06    789.0  221528.50
#
#
#                              50%         75%          max
# category_name
# Autos & Vehicles        406278.0  1074284.25   25244097.0
# Comedy                  980236.0  1877801.00   29178096.0
# Education               419440.5   772115.00    7349435.0
# Entertainment           734704.0  1733746.25  149376127.0
# Film & Animation       1274578.0  3227166.00   54863912.0
# Gaming                 1494142.0  3202761.00   16935442.0
# Howto & Style           502783.0  1098035.75   54155921.0
# Music                  1434128.0  4947952.75  225211923.0
# News & Politics         244014.0   685282.00   10277358.0
# Nonprofits & Activism    73649.0   316467.00   24286474.0
# People & Blogs          599139.0  1686941.50   56111957.0
# Pets & Animals          444501.5   941298.75    6187457.0
# Science & Technology    585748.0  1375783.00   42799458.0
# Shows                  1155692.0  1309964.00    1445949.0
# Sports                  559352.0  1406208.50   29090799.0
# Travel & Events         494825.5   985693.25   23932421.0

# %%
#create box plot for 
df_colname = ['views', 'likes', 'dislikes', 'comment_count']
fig, axes = plt.subplots(2, 2, figsize=(20, 15))
for i, col in enumerate(df_colname):
    
    box = sns.boxplot(x=df_colname[i], y='category_name', data=trending_df, whis="range", palette="vlag", ax=axes[i // 2, i % 2])
    box.set(xscale="log") #rescale boxplot x-axis with log
    axes[i // 2, i % 2].set_title(df_colname[i].capitalize()+ ' in each video')

fig.subplots_adjust(wspace=.4)

# %%
# create a pivot table to calculate the "total" number of videos upload, views, likes, dislikes, comment counts, days spend to trend in each category
trending_pi = pd.pivot_table(trending_df, values=['views', 'likes', 'dislikes', 'comment_count', 'video_id', 'days_spent_to_trend'], 
                             index=['category_name'], aggfunc={'views': np.sum, 'likes': np.sum, 'dislikes': np.sum, 
                                                            'comment_count': np.sum,'video_id': 'count', 
                                                               'days_spent_to_trend':np.sum})

trending_pi = trending_pi[['video_id', 'views', 'likes', 'dislikes', 'comment_count', 'days_spent_to_trend']]
trending_pi.columns = ['video_count', 'views', 'likes', 'dislikes', 'comment_count', 'days_spent_to_trend']
trending_pi = trending_pi.sort_values('video_count', ascending=False)

# %%
trending_pi
# Out:
#                        video_count        views       likes  dislikes  \
# category_name
# Entertainment                 9964  20604388195   530516491  42987663
# Music                         6472  40132892190  1416838584  51179008
# Howto & Style                 4146   4078545064   162880075   5473899
# Comedy                        3457   5117426208   216346746   7230391
# People & Blogs                3210   4917191726   186615999  10187901
# News & Politics               2487   1473765704    18151033   4180049
# Science & Technology          2401   3487756816    82532638   4548402
# Film & Animation              2345   7284156721   165997476   6075148
# Sports                        2174   4404456673    98621211   5133551
# Education                     1656   1180629990    49257772   1351972
# Pets & Animals                 920    764651989    19370702    527379
# Gaming                         817   2141218625    69038284   9184466
# Travel & Events                402    343557084     4836246    340427
# Autos & Vehicles               384    520690717     4245656    243010
# Nonprofits & Activism           57    168941392    14815646   3310381
# Shows                           57     51501058     1082639     24508
#
#                        comment_count  days_spent_to_trend
# category_name
# Entertainment               73566498               129617
# Music                      125296396                95292
# Howto & Style               23149550                32809
# Comedy                      22545582                34941
# People & Blogs              24778032                50350
# News & Politics              6039433                46213
# Science & Technology        11989926                43612
# Film & Animation            17887060                96286
# Sports                      11192155                50992
# Education                    5442242                62870
# Pets & Animals               2660705                 7106
# Gaming                      14740713                17936
# Travel & Events               911511                 2837
# Autos & Vehicles              784447                16591
# Nonprofits & Activism        4808797                  307
# Shows                          95117                  611

# %%
# find categories that do not enter the trending videos 
trendcat = list(trending_pi.index)
catList = list(category_dict.values())
not_trend_cat = []
for i in range(len(catList)):
    if catList[i] not in trendcat:
        not_trend_cat.append(catList[i])
print(len(not_trend_cat))
print(not_trend_cat)
# Out:
# 15
# ['Short Movies', 'Videoblogging', 'Movies', 'Anime/Animation', 'Action/Adventure', 'Classics', 'Documentary', 'Drama', 'Family', 'Foreign', 'Horror', 'Sci-Fi/Fantasy', 'Thriller', 'Shorts', 'Trailers']

# %%
# count average number of 'views', 'likes', 'dislikes', 'comment_count', 'days_spent_to_trend' per video in each category
trending_pi_avg = trending_pi[['views', 'likes', 'dislikes', 'comment_count', 'days_spent_to_trend']].div(trending_pi['video_count'], axis=0).round(2)

# calculate the percentage of likes and dislikes
trending_pi_avg['likes(%)'] = trending_pi_avg['likes'] / (trending_pi_avg['likes'] + trending_pi_avg['dislikes'])
trending_pi_avg['dislikes(%)'] = trending_pi_avg['dislikes'] / (trending_pi_avg['likes'] + trending_pi_avg['dislikes'])

trending_pi_avg.columns = ['Avg Views', 'Avg Likes','Avg Dislikes','Avg Comment Count', 'Avg Days Spent to Trend', 'Likes(%)', 'Dislikes(%)']

# %%
cm = sns.light_palette(sns.color_palette()[0], as_cmap=True)
s2 = trending_pi_avg.style.background_gradient(cmap=cm)
s2
# Out:
# <style  type="text/css" >
#     #T_997390c6_6659_11e9_97b1_acde48001122row0_col0 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row0_col1 {
#             background-color:  #c5ddee;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row0_col2 {
#             background-color:  #dcecf7;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row0_col3 {
#             background-color:  #dcecf7;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row0_col4 {
#             background-color:  #c1dbed;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row0_col5 {
#             background-color:  #5f9fcb;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row0_col6 {
#             background-color:  #a9cce5;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row1_col0 {
#             background-color:  #1f77b4;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row1_col1 {
#             background-color:  #408bbf;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row1_col2 {
#             background-color:  #cfe4f2;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row1_col3 {
#             background-color:  #bed9ec;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row1_col4 {
#             background-color:  #b7d5ea;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row1_col5 {
#             background-color:  #2e80b9;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row1_col6 {
#             background-color:  #daebf6;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row2_col0 {
#             background-color:  #dcecf7;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row2_col1 {
#             background-color:  #d0e4f2;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row2_col2 {
#             background-color:  #e7f2fa;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row2_col3 {
#             background-color:  #e0eef8;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row2_col4 {
#             background-color:  #dcecf7;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row2_col5 {
#             background-color:  #2c7fb8;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row2_col6 {
#             background-color:  #ddecf7;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row3_col0 {
#             background-color:  #cae0f0;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row3_col1 {
#             background-color:  #bdd8ec;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row3_col2 {
#             background-color:  #e4f0f9;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row3_col3 {
#             background-color:  #ddedf7;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row3_col4 {
#             background-color:  #d1e5f3;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row3_col5 {
#             background-color:  #2b7eb8;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row3_col6 {
#             background-color:  #ddedf7;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row4_col0 {
#             background-color:  #c8dff0;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row4_col1 {
#             background-color:  #c1dbed;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row4_col2 {
#             background-color:  #e0eef8;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row4_col3 {
#             background-color:  #dbebf6;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row4_col4 {
#             background-color:  #b3d2e8;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row4_col5 {
#             background-color:  #438dc1;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row4_col6 {
#             background-color:  #c6deef;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row5_col0 {
#             background-color:  #e9f4fb;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row5_col1 {
#             background-color:  #e9f4fb;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row5_col2 {
#             background-color:  #e5f1fa;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row5_col3 {
#             background-color:  #e8f3fb;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row5_col4 {
#             background-color:  #a3c8e2;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row5_col5 {
#             background-color:  #e9f4fb;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row5_col6 {
#             background-color:  #1f77b4;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row6_col0 {
#             background-color:  #cae1f0;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row6_col1 {
#             background-color:  #d4e7f4;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row6_col2 {
#             background-color:  #e4f1fa;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row6_col3 {
#             background-color:  #e1eff8;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row6_col4 {
#             background-color:  #a5cae3;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row6_col5 {
#             background-color:  #438ec1;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row6_col6 {
#             background-color:  #c5ddee;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row7_col0 {
#             background-color:  #8fbcdb;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row7_col1 {
#             background-color:  #b6d5e9;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row7_col2 {
#             background-color:  #e2eff9;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row7_col3 {
#             background-color:  #dbebf6;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row7_col4 {
#             background-color:  #2a7eb8;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row7_col5 {
#             background-color:  #2f81ba;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row7_col6 {
#             background-color:  #d9eaf6;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row8_col0 {
#             background-color:  #b6d4e9;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row8_col1 {
#             background-color:  #cbe1f1;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row8_col2 {
#             background-color:  #e3f0f9;
#             color:  #000000;
#         }    #T_997390c6_6659_11e9_97b1_acde48001122row8_col3 {
#             background-color:  #e1eff8;
#             color:  #000000;

# %%
# %%
# # Use Barchart to visualize the data
# colname = ['Avg Views', 'Avg Likes','Avg Dislikes','Avg Comment Count']
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# for i, col in enumerate(colname):
#     if i != len(colname)-1:
#         sns.barplot(data = trending_pi_avg, x = trending_pi_avg.index, y = col, ax=axes[i // 2, i % 2])
#     else:
#         sns.barplot(data = trending_pi_avg, x = trending_pi_avg.index, y = col, ax=axes[i // 2, i % 2], hue=trending_pi_avg.index, dodge=False)
#     axes[i // 2, i % 2].set_xticklabels('')
#     axes[i // 2, i % 2].set_title(colname[i].capitalize()+ ' in each video')
#
#
# fig.subplots_adjust(wspace=.4)
# plt.legend(bbox_to_anchor=(1.05, 2.225), loc=2, ncol=1)
# Out:
# UsageError: Cell magic `%%` not found.

# %%
def highlight_min(s):
    '''
    highlight the minimum in a Series or DataFrame
    '''
    is_min = s == s.min()
    return ['background-color: orange' if v else '' for v in is_min]

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
#check the statistic summary of days spent to trend in each category
days_describe = trending_df[['category_name', 'days_spent_to_trend']].groupby('category_name').describe()
s = days_describe.style.apply(highlight_min).apply(highlight_max)
s
# Out:
# <style  type="text/css" >
#     #T_a151b778_6659_11e9_97b1_acde48001122row0_col1 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row0_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row1_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row2_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row3_col0 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row3_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row3_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row4_col2 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row4_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row5_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row6_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row7_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row8_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row8_col5 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row8_col6 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row9_col0 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row9_col1 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row9_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row9_col3 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row9_col7 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row10_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row11_col3 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row12_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row13_col0 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row13_col3 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row13_col4 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row13_col5 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row13_col6 {
#             : ;
#             background-color:  yellow;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row14_col3 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row14_col4 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row14_col5 {
#             background-color:  orange;
#             : ;
#         }    #T_a151b778_6659_11e9_97b1_acde48001122row15_col3 {
#             background-color:  orange;
#             : ;
#         }</style><table id="T_a151b778_6659_11e9_97b1_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=8>days_spent_to_trend</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >count</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >std</th>        <th class="col_heading level1 col3" >min</th>        <th class="col_heading level1 col4" >25%</th>        <th class="col_heading level1 col5" >50%</th>        <th class="col_heading level1 col6" >75%</th>        <th class="col_heading level1 col7" >max</th>    </tr>    <tr>        <th class="index_name level0" >category_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a151b778_6659_11e9_97b1_acde48001122level0_row0" class="row_heading level0 row0" >Autos & Vehicles</th>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col0" class="data row0 col0" >384</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col1" class="data row0 col1" >43.2057</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col2" class="data row0 col2" >211.839</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col4" class="data row0 col4" >3</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col5" class="data row0 col5" >5</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col6" class="data row0 col6" >7</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row0_col7" class="data row0 col7" >1771</td>
#             </tr>
#             <tr>
#                         <th id="T_a151b778_6659_11e9_97b1_acde48001122level0_row1" class="row_heading level0 row1" >Comedy</th>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col0" class="data row1 col0" >3457</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col1" class="data row1 col1" >10.1073</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col2" class="data row1 col2" >80.2936</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col5" class="data row1 col5" >5</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col6" class="data row1 col6" >8</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row1_col7" class="data row1 col7" >1951</td>
#             </tr>
#             <tr>
#                         <th id="T_a151b778_6659_11e9_97b1_acde48001122level0_row2" class="row_heading level0 row2" >Education</th>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row2_col0" class="data row2 col0" >1656</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row2_col1" class="data row2 col1" >37.965</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row2_col2" class="data row2 col2" >267.755</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row2_col5" class="data row2 col5" >5</td>
#                         <td id="T_a151b778_6659_11e9_97b1_acde48001122row2_col6" class="data row2 col6" >8</td>

# %%
# sns.barplot(data = trending_pi_avg, x = trending_pi_avg.index, y = 'Avg Days Spent to Trend', dodge=False)
# sns.set(rc={'figure.figsize':(20,5)})
colors = plt.cm.tab20(np.linspace(0, 1, 20))
ax = trending_pi_avg['Avg Days Spent to Trend'].plot(kind='bar', align='center', figsize=(10,4),
                                                       color=colors,title='Average Days Spent to Trend')
ax.set_xlabel("Category")
ax.set_ylabel("Percentage")
ax.set_xticklabels(trending_pi_avg.index)
ax

# %% [markdown]
# ### Findings
#
# According to the result, most of the videos spent average 1 to 10 days to become trending videos. There are some outliers spend within 1 day to trend, while others spent years to trend. Entertainment type has the most trending videos, and music, howto & style, comedy, people & blogs, news & politics are other famous types. 15 categories such as movies, animation, documentary did not have any trending videos from 2017-11-14 to 2018-06-14.
#
# Although entertainment videos have the most trending videos during the data captured period, it does not mean filming entertainment videos will definitely make your videos trend more. The proportion of "num of trending videos / num of videos upload entertainment" may not be the highest.
#
# However, there is no data to know how many numbers of videos upload during a specific period so it is hard to know the percentage of trending videos among the number of uploads in one category. Therefore, it is necessary to find other indicators such as num of views/likes/dislikes/comments in per trending video, average time a video need to spend from publish to upload.
#
# Another interesting findings is that despite of the least trending video counts among the categories, average likes, dislikes, number of comments per video of nonprofits & activism videos is the highests, and the days it spent to trend were shorter than most of the categories.

# %% [markdown]
# ## Hypothesis 4
# ### Top 250 Youtubers may have more trending videos than other Youtube channels.
#
# Original Hypothesis: The video category that has the most trending videos will have more subscribers than other categories.
# - Does top 250 youtubers (by grade, subs, views) means they have they most trending videos
# - Does most categories with most trending videos in accordance with the most profitable categories?

# %%
# load data
top250_subs_df = pd.read_csv('data/top250_us_youtube_by_subs.csv')
top250_views_df = pd.read_csv('data/top250_us_youtube_by_views.csv')

# %%
len(top250_subs_df.columns)
# Out:
# 20

# %%
def drop_col0(df):
    """ This function drop the Unnamed 0 column from the dataframe.

    :param df: dataframe
    :return: a clean dataframe
    """
    df = df.drop(df.columns[0], axis=1)
    return df

# %%
top250_subs_df = drop_col0(top250_subs_df)
top250_subs_df.head()
# Out:
#    US Rank Grade                        Name  Uploads  Subscribers  \
# 0        1    A+                   PewDiePie     3806     94275479
# 1        2    A+             5-Minute Crafts     2973     53832999
# 2        3   A++  Cocomelon - Nursery Rhymes      416     44131654
# 3        4    A+                         WWE    40805     42100827
# 4        5     A                Dude Perfect      202     41275631
#
#          Views       Category    Created Date  Daily Average Subs  \
# 0  21161543119  Entertainment  Apr 29th, 2010              146229
# 1  13291598454          Howto  Nov 15th, 2016               64674
# 2  25541274029      Education   Sep 1st, 2006              125711
# 3  31435620458         Sports  May 11th, 2007               45303
# 4   7684220326         Sports  Mar 17th, 2009               37131
#
#    Daily Average Views  Min Daily Earning  Max Daily Earning  \
# 0             13416000             3400.0              53700
# 1             15396600             3800.0              61600
# 2             88514800            22100.0             354100
# 3             24296400             6100.0              97200
# 4              7820910             2000.0              31300
#
#    Min Monthly Earning  Max Monthly Earning  Min Yearly Earning  \
# 0               100600              1600000             1200000
# 1               115500              1800000             1400000
# 2               663900             10600000             8000000
# 3               182200              2900000             2200000
# 4                58700               938500              703900
#
#    Max Yearly Earning  World Subscriber Rank  World Video View Rank  \
# 0            19300000                      3                     11
# 1            22200000                      7                     36
# 2           127500000                     11                      7
# 3            35000000                     12                      3
# 4            11300000                     13                    111
#
#                                                  URL
# 0     https://socialblade.com/youtube/user/pewdiepie
# 1  https://socialblade.com/youtube/user/295-dw_td...
# 2     https://socialblade.com/youtube/user/checkgate
# 3  https://socialblade.com/youtube/user/wwefannation
# 4    https://socialblade.com/youtube/user/corycotton

# %% [markdown]
# ### Data Preprocessing

# %%
# check whether the category names are the same in two datasets
print(top250_subs_df['Category'].unique(), '\n')
print(trending_pi_avg.index)
# Out:
# ['Entertainment' 'Howto' 'Education' 'Sports' 'Music' 'News' 'Film'
#  'Comedy' 'Games' 'People' nan 'Nonprofit' 'Animals' 'Tech']
#
# Index(['Entertainment', 'Music', 'Howto & Style', 'Comedy', 'People & Blogs',
#        'News & Politics', 'Science & Technology', 'Film & Animation', 'Sports',
#        'Education', 'Pets & Animals', 'Gaming', 'Travel & Events',
#        'Autos & Vehicles', 'Nonprofits & Activism', 'Shows'],
#       dtype='object', name='category_name')

# %%
catname_dict = {'Entertainment': 'Entertainment', 'Howto': 'Howto & Style', 'Education': 'Education', 'Sports': 'Sports', 
                'Music': 'Music', 'News': 'News & Politics', 'Film': 'Film & Animation', 'Comedy':'Comedy', 'Games':'Gaming', 'People': 'People & Blogs',
               'Nonprofit': 'Nonprofits & Activism', 'Animals': 'Pets & Animals', 'Tech': 'Science & Technology'}

# %%
# change the category name to the same as trending videos dataset
top250_subs_df = top250_subs_df.replace(catname_dict) 
top250_subs_df['Category'].unique()
# Out:
# array(['Entertainment', 'Howto & Style', 'Education', 'Sports', 'Music',
#        'News & Politics', 'Film & Animation', 'Comedy', 'Gaming',
#        'People & Blogs', nan, 'Nonprofits & Activism', 'Pets & Animals',
#        'Science & Technology'], dtype=object)

# %%
max_earn = top250_subs_df['Max Monthly Earning'].astype(int)
min_earn = top250_subs_df['Min Monthly Earning'].astype(int)

top250_subs_df['Avg Monthly Earnings'] = (max_earn + min_earn) / 2

# %% [markdown]
# ### The video category that has the most trending videos will have more subscribers than other categories.

# %%
top250_pi = pd.pivot_table(top250_subs_df, values=['Uploads', 'Subscribers', 'Views', 'Avg Monthly Earnings'], 
                             index=['Category'], aggfunc=np.sum)
top250_pi
# Out:
#                        Avg Monthly Earnings  Subscribers  Uploads  \
# Category
# Comedy                            2029955.0    254399126    20531
# Education                         8365100.0    141720620     9464
# Entertainment                    13191136.0    851742251    92339
# Film & Animation                  3384128.5    128477793    44172
# Gaming                            3879950.0    281896672   200604
# Howto & Style                     2482896.0    205081512    11927
# Music                            13715329.5   1308052631    29794
# News & Politics                     41100.0     37592720      346
# Nonprofits & Activism              180150.0     18241267   131855
# People & Blogs                    2329741.5    189862946    25276
# Pets & Animals                      65450.0     14237121      520
# Science & Technology               252100.0     41278242     5721
# Sports                            2229450.0     94547737    71597
#
#                               Views
# Category
# Comedy                  73047997574
# Education               73128327918
# Entertainment          278771091821
# Film & Animation        54455689097
# Gaming                  99185898917
# Howto & Style           37826732048
# Music                  455643106523
# News & Politics          2260660195
# Nonprofits & Activism    3252874897
# People & Blogs          66236348800
# Pets & Animals           2596020010
# Science & Technology     5705200278
# Sports                  44647698044

# %%
trending_pi = trending_pi.reset_index()
top250_pi = top250_pi.reset_index()

# %%
trending_top250 = pd.merge(trending_pi, top250_pi, left_on='category_name', right_on='Category', how='left', indicator=True)
trending_top250
# Out:
#             category_name  video_count        views       likes  dislikes  \
# 0           Entertainment         9964  20604388195   530516491  42987663
# 1                   Music         6472  40132892190  1416838584  51179008
# 2           Howto & Style         4146   4078545064   162880075   5473899
# 3                  Comedy         3457   5117426208   216346746   7230391
# 4          People & Blogs         3210   4917191726   186615999  10187901
# 5         News & Politics         2487   1473765704    18151033   4180049
# 6    Science & Technology         2401   3487756816    82532638   4548402
# 7        Film & Animation         2345   7284156721   165997476   6075148
# 8                  Sports         2174   4404456673    98621211   5133551
# 9               Education         1656   1180629990    49257772   1351972
# 10         Pets & Animals          920    764651989    19370702    527379
# 11                 Gaming          817   2141218625    69038284   9184466
# 12        Travel & Events          402    343557084     4836246    340427
# 13       Autos & Vehicles          384    520690717     4245656    243010
# 14  Nonprofits & Activism           57    168941392    14815646   3310381
# 15                  Shows           57     51501058     1082639     24508
#
#     comment_count  days_spent_to_trend               Category  \
# 0        73566498               129617          Entertainment
# 1       125296396                95292                  Music
# 2        23149550                32809          Howto & Style
# 3        22545582                34941                 Comedy
# 4        24778032                50350         People & Blogs
# 5         6039433                46213        News & Politics
# 6        11989926                43612   Science & Technology
# 7        17887060                96286       Film & Animation
# 8        11192155                50992                 Sports
# 9         5442242                62870              Education
# 10        2660705                 7106         Pets & Animals
# 11       14740713                17936                 Gaming
# 12         911511                 2837                    NaN
# 13         784447                16591                    NaN
# 14        4808797                  307  Nonprofits & Activism
# 15          95117                  611                    NaN
#
#     Avg Monthly Earnings   Subscribers   Uploads         Views     _merge
# 0             13191136.0  8.517423e+08   92339.0  2.787711e+11       both
# 1             13715329.5  1.308053e+09   29794.0  4.556431e+11       both
# 2              2482896.0  2.050815e+08   11927.0  3.782673e+10       both
# 3              2029955.0  2.543991e+08   20531.0  7.304800e+10       both
# 4              2329741.5  1.898629e+08   25276.0  6.623635e+10       both
# 5                41100.0  3.759272e+07     346.0  2.260660e+09       both
# 6               252100.0  4.127824e+07    5721.0  5.705200e+09       both
# 7              3384128.5  1.284778e+08   44172.0  5.445569e+10       both
# 8              2229450.0  9.454774e+07   71597.0  4.464770e+10       both
# 9              8365100.0  1.417206e+08    9464.0  7.312833e+10       both
# 10               65450.0  1.423712e+07     520.0  2.596020e+09       both
# 11             3879950.0  2.818967e+08  200604.0  9.918590e+10       both
# 12                   NaN           NaN       NaN           NaN  left_only
# 13                   NaN           NaN       NaN           NaN  left_only
# 14              180150.0  1.824127e+07  131855.0  3.252875e+09       both
# 15                   NaN           NaN       NaN           NaN  left_only

# %% [markdown]
# None of the Top 250 Youtubers set their channel types as 'Travel & Events', 'Autos & Vehicles', 'Shows', which have trending videos in the given time. These categories do have less trending video

# %%
trending_top250[['category_name', 'video_count', 'Subscribers']]
# Out:
#             category_name  video_count   Subscribers
# 0           Entertainment         9964  8.517423e+08
# 1                   Music         6472  1.308053e+09
# 2           Howto & Style         4146  2.050815e+08
# 3                  Comedy         3457  2.543991e+08
# 4          People & Blogs         3210  1.898629e+08
# 5         News & Politics         2487  3.759272e+07
# 6    Science & Technology         2401  4.127824e+07
# 7        Film & Animation         2345  1.284778e+08
# 8                  Sports         2174  9.454774e+07
# 9               Education         1656  1.417206e+08
# 10         Pets & Animals          920  1.423712e+07
# 11                 Gaming          817  2.818967e+08
# 12        Travel & Events          402           NaN
# 13       Autos & Vehicles          384           NaN
# 14  Nonprofits & Activism           57  1.824127e+07
# 15                  Shows           57           NaN

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

g1 = sns.scatterplot(x="video_count", y="Subscribers", data=trending_top250, ax=axes[0])
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)
axes[0].set_title('Trending video counts vs Total subs')


g2 = sns.barplot(data = trending_top250, x = trending_top250['category_name'], y = 'video_count', ax=axes[1])
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)
axes[1].set_title('Trending video count in each category')

g3 = sns.barplot(data = trending_top250, x = trending_top250['category_name'], y = 'Subscribers', ax=axes[2])
axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
axes[2].set_title('Top250 total subs in each category')



fig.subplots_adjust(wspace=.3)
# plt.legend(bbox_to_anchor=(1.05, 2.225), loc=2, ncol=1)

# %% [markdown]
# ### Does most categories with most trending videos also the most profitable categories?

# %%
trending_top250[['category_name', 'video_count', 'Avg Monthly Earnings']]
# Out:
#             category_name  video_count  Avg Monthly Earnings
# 0           Entertainment         9964            13191136.0
# 1                   Music         6472            13715329.5
# 2           Howto & Style         4146             2482896.0
# 3                  Comedy         3457             2029955.0
# 4          People & Blogs         3210             2329741.5
# 5         News & Politics         2487               41100.0
# 6    Science & Technology         2401              252100.0
# 7        Film & Animation         2345             3384128.5
# 8                  Sports         2174             2229450.0
# 9               Education         1656             8365100.0
# 10         Pets & Animals          920               65450.0
# 11                 Gaming          817             3879950.0
# 12        Travel & Events          402                   NaN
# 13       Autos & Vehicles          384                   NaN
# 14  Nonprofits & Activism           57              180150.0
# 15                  Shows           57                   NaN

# %%
g4 = sns.scatterplot(x="video_count", y="Avg Monthly Earnings", data=trending_top250)
g4.set_title('Trending video counts vs Avg Monthly Earnings')
# Out:
# Text(0.5, 1.0, 'Trending video counts vs Avg Monthly Earnings')

# %% [markdown]
# ### Does top 250 youtubers means they have they most trending videos
# #### Find the Top Youtube channels that have trending videos

# %% [markdown]
# - Does top 250 youtubers (by grade, subs, views) means they have the most trending videos
# - Does most categories with most trending videos in accordance with the most profitable categories? (Min + Max / 2)

# %%
trending_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id publish_time  \
# 0           22   2017-11-13
# 1           24   2017-11-13
# 2           23   2017-11-12
# 3           24   2017-11-13
# 4           24   2017-11-12
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  ...                                  thumbnail_link  \
# 0      2966  ...  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146  ...  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339  ...  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666  ...  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989  ...  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#   comments_disabled  ratings_disabled  video_error_or_removed  \
# 0             False             False                   False
# 1             False             False                   False
# 2             False             False                   False
# 3             False             False                   False
# 4             False             False                   False
#
#                                          description   category_name  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  People & Blogs
# 1  One year after the presidential election, John...   Entertainment
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...          Comedy
# 3  Today we find out if Link is a Nickelback amat...   Entertainment
# 4  I know it's been a while since we did this sho...   Entertainment
#
#   days_spent_to_trend  Month  Year   trend_MY
# 0                   1     11  2017 2017-11-01
# 1                   1     11  2017 2017-11-01
# 2                   2     11  2017 2017-11-01
# 3                   1     11  2017 2017-11-01
# 4                   2     11  2017 2017-11-01
#
# [5 rows x 21 columns]

# %%
unique_trend = trending_df.groupby(['channel_title'])['title'].nunique().to_frame()
unique_trend.columns = ['count_trending']
unique_trend = unique_trend.reset_index()

# %%
unique_trend.head(10)
# Out:
#                                        channel_title  count_trending
# 0                                            12 News               1
# 1                              1MILLION Dance Studio               4
# 2                                       1theK (원더케이)               5
# 3                                   20th Century Fox              17
# 4                                            2CELLOS               1
# 5                                        3Blue1Brown               3
# 6                                   3D Printing Nerd               2
# 7  42Fab - Metalworking and Multi-Medium Fabrication               1
# 8                                              494ta               1
# 9                                       4given4ever1               1

# %%
# find the rank of count_trending 
def get_rank(df, title, count):
    """ This function calculated the rank of the number of trending videos of Top 250 Youtube channels
    
    :param title: channel titles that derive from the dataframe
    :param title: column name that represents the channel titles
    :param count: column name that represents the trending video counts
    :return: a list of ranks
    """ 
    new_df = df[[title, count]].sort_values(by=count, ascending=False)
    
    
    rank = []
    count = list(new_df[count])
    for i in range(len(count)):
        if len(rank) == 0: # if list is empty
            rank.append(i+1)
        else:
            if count[i] == count[i-1]: # if same as the previous one
                rank.append(rank[i-1])
            else:
                rank.append(i+1)
    return rank

# %%
unique_trend_temp = unique_trend[['channel_title', 'count_trending']].sort_values(by='count_trending', ascending=False)
count_rank = get_rank(unique_trend_temp, 'channel_title', 'count_trending')

unique_trend_temp["count_rank"] = count_rank

# %%
unique_trend_temp.head()
# Out:
#                                channel_title  count_trending  count_rank
# 555                                     ESPN              84           1
# 1804                            TheEllenShow              74           2
# 1785  The Tonight Show Starring Jimmy Fallon              72           3
# 889                        Jimmy Kimmel Live              70           4
# 1753      The Late Show with Stephen Colbert              58           5

# %%
top250_views_df = drop_col0(top250_views_df)

# %%
top250_views_df.head()
# Out:
#    US Rank Grade                        Name  Uploads Subscribers  \
# 0        1    A+                         WWE    40805    42099730
# 1        2    A+             Ryan ToysReview     1356    18989260
# 2        3   A++  Cocomelon - Nursery Rhymes      416    44127136
# 3        4    A+                  Movieclips    32246    24964732
# 4        5    A+                   PewDiePie     3806    94272352
#
#          Views       Category    Created Date Daily Average Subs  \
# 0  31435620458         Sports  May 11th, 2007              45303
# 1  28730791075  Entertainment  Mar 17th, 2015              11527
# 2  25541274029      Education   Sep 1st, 2006             125711
# 3  22285854340           Film  Apr 28th, 2006              37300
# 4  21161543119  Entertainment  Apr 29th, 2010             146229
#
#    Daily Average Views  Min Daily Earning  Max Daily Earning  \
# 0             24296400               6100              97200
# 1             19519500               4900              78100
# 2             88514800              22100             354100
# 3             25595300               6400             102400
# 4             13416000               3400              53700
#
#    Min Monthly Earning  Max Monthly Earning  Min Yearly Earning  \
# 0               182200              2900000             2200000
# 1               146400              2300000             1800000
# 2               663900             10600000             8000000
# 3               192000              3100000             2300000
# 4               100600              1600000             1200000
#
#    Max Yearly Earning  World Subscriber Rank  World Video View Rank  \
# 0            35000000                     12                      3
# 1            28100000                    101                      4
# 2           127500000                     11                      7
# 3            36900000                     46                     10
# 4            19300000                      3                     11
#
#                                                  URL
# 0  https://socialblade.com/youtube/user/wwefannation
# 1  https://socialblade.com/youtube/user/hgjghz9so...
# 2     https://socialblade.com/youtube/user/checkgate
# 3    https://socialblade.com/youtube/user/movieclips
# 4     https://socialblade.com/youtube/user/pewdiepie

# %%
def merge_trend(df1, df2):
    """ This function merges the top youtube channel information and the video rank information together
    
    :param df1: dataframe that consists of the top youtube channel information
    :param df2: dataframe that consists of trending video rank information
    :return: a merged dataframe
    """ 
    new_df = pd.merge(df1, df2, left_on='Name',right_on='channel_title', how='left', indicator=True)
    
    new_df['count_trending'] = new_df['count_trending'].fillna(0)
    new_df['count_rank'] = new_df['count_rank'].fillna(max(df2['count_rank'])+1)
    
    return new_df

# %%
top250_trend_views = merge_trend(top250_views_df, unique_trend_temp)
top250_trend_subs = merge_trend(top250_subs_df, unique_trend_temp)

# %%
top250_trend_views.head()
# Out:
#    US Rank Grade                        Name  Uploads Subscribers  \
# 0        1    A+                         WWE    40805    42099730
# 1        2    A+             Ryan ToysReview     1356    18989260
# 2        3   A++  Cocomelon - Nursery Rhymes      416    44127136
# 3        4    A+                  Movieclips    32246    24964732
# 4        5    A+                   PewDiePie     3806    94272352
#
#          Views       Category    Created Date Daily Average Subs  \
# 0  31435620458         Sports  May 11th, 2007              45303
# 1  28730791075  Entertainment  Mar 17th, 2015              11527
# 2  25541274029      Education   Sep 1st, 2006             125711
# 3  22285854340           Film  Apr 28th, 2006              37300
# 4  21161543119  Entertainment  Apr 29th, 2010             146229
#
#    Daily Average Views  ...  Max Monthly Earning  Min Yearly Earning  \
# 0             24296400  ...              2900000             2200000
# 1             19519500  ...              2300000             1800000
# 2             88514800  ...             10600000             8000000
# 3             25595300  ...              3100000             2300000
# 4             13416000  ...              1600000             1200000
#
#    Max Yearly Earning  World Subscriber Rank  World Video View Rank  \
# 0            35000000                     12                      3
# 1            28100000                    101                      4
# 2           127500000                     11                      7
# 3            36900000                     46                     10
# 4            19300000                      3                     11
#
#                                                  URL  channel_title  \
# 0  https://socialblade.com/youtube/user/wwefannation            WWE
# 1  https://socialblade.com/youtube/user/hgjghz9so...            NaN
# 2     https://socialblade.com/youtube/user/checkgate            NaN
# 3    https://socialblade.com/youtube/user/movieclips            NaN
# 4     https://socialblade.com/youtube/user/pewdiepie      PewDiePie
#
#    count_trending count_rank     _merge
# 0            34.0       17.0       both
# 1             0.0      848.0  left_only
# 2             0.0      848.0  left_only
# 3             0.0      848.0  left_only
# 4             1.0      847.0       both
#
# [5 rows x 23 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 4))

g1 = sns.scatterplot(x="US Rank", y="count_rank", data=top250_trend_views, ax=axes[0])
axes[1].set_title('US View Rank vs Trending Video Rank')

g2 = sns.scatterplot(x="US Rank", y="count_rank", data=top250_trend_subs, ax=axes[1])
axes[1].set_title('US Subscribers Rank vs Trending Video Rank')
# Out:
# Text(0.5, 1.0, 'US Subscribers Rank vs Trending Video Rank')

# %%
# calculate the proportion of trending videos uploaded by Top 250 channels based on views and world total trending videos 
top250_trend_views['count_trending'].sum() / unique_trend_temp['count_trending'].sum()
# Out:
# 0.14502164502164502

# %%
# count number of Youtubers that have trending videos in given time period
len(top250_trend_views[top250_trend_views['count_trending']!=0])
# Out:
# 95

# %%
# calculate the proportion of trending videos uploaded by Top 250 channels based on views and world total trending videos 
top250_trend_subs['count_trending'].sum() / unique_trend_temp['count_trending'].sum()
# Out:
# 0.15940012368583797

# %%
# count number of Youtubers that have trending videos in given time period
len(top250_trend_subs[top250_trend_subs['count_trending']!=0])
# Out:
# 124

# %% [markdown]
# ### Findings
#
# The result showed that having more more subscribers or video views, does not mean they will definitly have more trending videos in the given time. Although there is no direct relationship between ranks of subscriber or views and number of trending videos, the dataset demonstrates an interesting result when we compare the top YouTube channels with the entire YouTube channels in the world.
#
# Among the Top 250 US YouTube Channels based on number of subs or views, **around 40% - 50%** of them have trending videos in the given time period, which accounted for **around 15%** of the numbers trending videos in the given time. According to SocialBlade and Youtube statistics, YouTube is launched in 91 countries and there are around 23 million YouTube channels in the world. Top 250 US Youtube channels are only **0.001%** of the total number of youtube channels in the world. This showed how the small proportion of the channels play important roles in contributing to the increase of the Youtube video views for the platform.
